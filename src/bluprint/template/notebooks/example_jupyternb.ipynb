# %% [markdown]
# # Example notebook

# %% [markdown]
# Import function from the project package to use in the notebook:

# %%
from {{placeholder_name}}.example import add_one

# %%
add_one(3.14)

# %% [markdown]
# Load configuration and data:

# %%
from bluprint.config import load_data_yaml

data = load_data_yaml()

# Path to the example dataset
data['example']

# %% [markdown]
# Print the file contents:

# %%
with open(data['example']) as data_file:
    for line in data_file:
        print(line)
